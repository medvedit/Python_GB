# %%
from sympy import *


x = symbols('x')
fan = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30
nonlinsolve([fan,0], [x])
# Out:
# ConditionSet((x,), Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), ProductSet(Complexes))

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')
def f(x):
    return -12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x - 30

plot(f(x), (x, -1, 1))

# %% [markdown]
# **f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30**
#
# 1. Определить корни уравнения f(x) = 0
# 2. Найти интервалы, на которых функция возрастает
# 3. Найти интервалы, на которых функция убывает
# 4. Построить график
# 5. Вычислить вершину
# 6. Определить промежутки, на котором f > 0
# 7. Определить промежутки, на котором f < 0

# %% [markdown]
# ### В диапазоне при x = -1 and 1 будут следующие значения:
#
# 1. Корни уравнения (приблизительно) x = -0,625, -0,13 и 0,8
# 2. Найти интервалы, на которых функция возрастает на участке Х: (-0,42; 0,48)
# 3. Найти интервалы, на которых функция убывает на участках х: (-1; -0,42) и (0,48; 1)
# 4. График отрисован.
# 5. Вычислить вершину: точки, где меняется направление функции (примерное значение) х  = -0,42 и х = 0,48
# 6. Определить промежутки, на котором f > 0: для х (-1; -0,625) и (-0,13; 0,8)
# 7. Определить промежутки, на котором f < 0: для х (-0,625; -0,13) и (0,8; 1)
